# %% [markdown]
# # Preprocessing the raw Pokemon data
#
# by GLoria

# %%
import numpy as np 
import pandas as pd 
import os

# %% [markdown]
# ### images
#
# getting pokemon names from the images we have so we can merge with complete dataset on pokemon names later
#
# source: https://www.kaggle.com/datasets/arenagrenade/the-complete-pokemon-images-data-set/code

# %%
_root = 'real_pokemon_data/pokemon_images'
filenames = sorted(os.listdir(_root))
filenames = pd.Series(filenames)

# %%
filenames
# Out:
# 0             abomasnow.png
# 1                  abra.png
# 2                 absol.png
# 3              accelgor.png
# 4      aegislash-shield.png
#                ...
# 893             zoroark.png
# 894               zorua.png
# 895               zubat.png
# 896            zweilous.png
# 897             zygarde.png
# Length: 898, dtype: object

# %%
image_df = pd.DataFrame()
image_df['name'] = [x[:-4] for x in filenames]
image_df
# Out:
#                  name
# 0           abomasnow
# 1                abra
# 2               absol
# 3            accelgor
# 4    aegislash-shield
# ..                ...
# 893           zoroark
# 894             zorua
# 895             zubat
# 896          zweilous
# 897           zygarde
#
# [898 rows x 1 columns]

# %% [markdown]
# embedding images into base64 and adding them to the df

# %%
import base64

def encode_image(image_path):
    with open(image_path, 'rb') as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# %%
image_df['image_base64'] = image_df.apply(lambda row: encode_image(f'real_pokemon_data/pokemon_images/{row['name']}.png'), axis=1)

# %%
image_df
# Out:
#                  name                                       image_base64
# 0           abomasnow  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 1                abra  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 2               absol  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 3            accelgor  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 4    aegislash-shield  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# ..                ...                                                ...
# 893           zoroark  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 894             zorua  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 895             zubat  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 896          zweilous  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 897           zygarde  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
#
# [898 rows x 2 columns]

# %% [markdown]
# ### stats dataset

# %%
stats_df = pd.read_csv('real_pokemon_data/pokemon_complete_dataset.csv')
stats_df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 0                 0.5            0.5            0.5           2.0
# 1                 0.5            0.5            0.5           2.0
# 2                 0.5            0.5            0.5           2.0
# 3                 1.0            0.5            1.0           0.5
# 4                 1.0            0.5            1.0           0.5
# ..                ...            ...            ...           ...
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 0               2.0            1.0  ...             88.1               1
# 1               2.0            1.0  ...             88.1               2
# 2               2.0            1.0  ...             88.1               3
# 3               1.0            1.0  ...             88.1               4
# 4               1.0            1.0  ...             88.1               5
# ..              ...            ...  ...              ...             ...
# 796             0.5            1.0  ...              NaN             797
# 797             1.0            1.0  ...              NaN             798
# 798             1.0            0.5  ...              NaN             799
# 799             1.0            2.0  ...              NaN             800
# 800             0.5            1.0  ...              NaN             801
#
#      sp_attack  sp_defense  speed    type1   type2  weight_kg  generation  \
# 0           65          65     45    grass  poison        6.9           1
# 1           80          80     60    grass  poison       13.0           1
# 2          122         120     80    grass  poison      100.0           1
# 3           60          50     65     fire     NaN        8.5           1
# 4           80          65     80     fire     NaN       19.0           1
# ..         ...         ...    ...      ...     ...        ...         ...
# 796        107         101     61    steel  flying      999.9           7
# 797         59          31    109    grass   steel        0.1           7
# 798         97          53     43     dark  dragon      888.0           7
# 799        127          89     79  psychic     NaN      230.0           7
# 800        130         115     65    steel   fairy       80.5           7
#
#      is_legendary
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 796             1
# 797             1
# 798             1
# 799             1
# 800             1
#
# [801 rows x 41 columns]

# %% [markdown]
# ### metadata
#
# source: https://www.kaggle.com/datasets/rounakbanik/pokemon
#
# - `name`: The English name of the Pokemon
# - `japanese_name`: The Original Japanese name of the Pokemon
# - `pokedex_number`: The entry number of the Pokemon in the National Pokedex
# - `percentage_male`: The percentage of the species that are male. Blank if the Pokemon is genderless.
# - `type1`: The Primary Type of the Pokemon
# - `type2`: The Secondary Type of the Pokemon
# - `classification`: The Classification of the Pokemon as described by the Sun and Moon Pokedex
# - `height_m`: Height of the Pokemon in metres
# - `weight_kg`: The Weight of the Pokemon in kilograms
# - `capture_rate`: Capture Rate of the Pokemon
# - `base_egg_steps`: The number of steps required to hatch an egg of the Pokemon
# - `abilities`: A stringified list of abilities that the Pokemon is capable of having
# - `experience_growth`: The Experience Growth of the Pokemon
# - `base_happiness`: Base Happiness of the Pokemon
# - `against_?`: Eighteen features that denote the amount of damage taken against an attack of a particular type
# - `hp`: The Base HP of the Pokemon
# - `attack`: The Base Attack of the Pokemon
# - `defense`: The Base Defense of the Pokemon
# - `sp_attack`: The Base Special Attack of the Pokemon
# - `sp_defense`: The Base Special Defense of the Pokemon
# - `speed`: The Base Speed of the Pokemon
# - `generation`: The numbered generation which the Pokemon was first introduced
# - `is_legendary`: Denotes if the Pokemon is legendary.

# %% [markdown]
# data cleaning (changing names to all lowercases)

# %%
stats_df['name'] = stats_df['name'].apply(str.lower)
stats_df['name']
# Out:
# 0       bulbasaur
# 1         ivysaur
# 2        venusaur
# 3      charmander
# 4      charmeleon
#           ...
# 796    celesteela
# 797       kartana
# 798      guzzlord
# 799      necrozma
# 800      magearna
# Name: name, Length: 801, dtype: object

# %% [markdown]
# check pokemons that are in the dataset and have image

# %%
complete_df = stats_df.merge(image_df, how='inner', left_on='name', right_on='name')
complete_df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 748              ['Beast Boost']         0.25           1.0             0.5
# 749              ['Beast Boost']         1.00           1.0             0.5
# 750              ['Beast Boost']         2.00           0.5             2.0
# 751              ['Prism Armor']         2.00           2.0             1.0
# 752               ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 0                 0.5            0.5            0.5           2.0
# 1                 0.5            0.5            0.5           2.0
# 2                 0.5            0.5            0.5           2.0
# 3                 1.0            0.5            1.0           0.5
# 4                 1.0            0.5            1.0           0.5
# ..                ...            ...            ...           ...
# 748               2.0            0.5            1.0           2.0
# 749               0.5            0.5            2.0           4.0
# 750               0.5            4.0            2.0           0.5
# 751               1.0            1.0            0.5           1.0
# 752               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  pokedex_number  sp_attack  \
# 0               2.0            1.0  ...               1         65
# 1               2.0            1.0  ...               2         80
# 2               2.0            1.0  ...               3        122
# 3               1.0            1.0  ...               4         60
# 4               1.0            1.0  ...               5         80
# ..              ...            ...  ...             ...        ...
# 748             0.5            1.0  ...             797        107
# 749             1.0            1.0  ...             798         59
# 750             1.0            0.5  ...             799         97
# 751             1.0            2.0  ...             800        127
# 752             0.5            1.0  ...             801        130
#
#      sp_defense  speed    type1   type2  weight_kg  generation  is_legendary  \
# 0            65     45    grass  poison        6.9           1             0
# 1            80     60    grass  poison       13.0           1             0
# 2           120     80    grass  poison      100.0           1             0
# 3            50     65     fire     NaN        8.5           1             0
# 4            65     80     fire     NaN       19.0           1             0
# ..          ...    ...      ...     ...        ...         ...           ...
# 748         101     61    steel  flying      999.9           7             1
# 749          31    109    grass   steel        0.1           7             1
# 750          53     43     dark  dragon      888.0           7             1
# 751          89     79  psychic     NaN      230.0           7             1
# 752         115     65    steel   fairy       80.5           7             1
#
#                                           image_base64
# 0    iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 1    iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 2    iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 3    iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 4    iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# ..                                                 ...
# 748  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 749  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 750  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 751  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
# 752  iVBORw0KGgoAAAANSUhEUgAAAdsAAAHbCAYAAACDejA0AA...
#
# [753 rows x 42 columns]

# %% [markdown]
# we have 753 pokemons with complete stats/info and image

# %% [markdown]
# exporting complete df into csv

# %%
# complete_df.to_csv('real_pokemon_data/preprocessed_data.csv')

# file too big, maybe not a good idea to turn image into base64
